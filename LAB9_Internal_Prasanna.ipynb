# %% [markdown]
# ## Time Series Prediction using LSTM

# %% [markdown]
# ### Download Data
# Link: https://datamarket.com/data/set/2324/daily-minimum-temperatures-in-melbourne-australia-1981-1990#!ds=2324&display=line
#
# #### Description
# Daily minimum temperatures in Melbourne, Australia, 1981-1990
#
# Units: Degrees Celcius
#
# #### Steps before loading
# - Rename the column name with temprature values to "Temprature"
# - In the last, there is one extra row in the data, remove it by opening the file and save it again.
# - There are some values in Temprature column which have a "?" before them, they will give error, remove "?" before them and save the file
# - If you don't want to do these steps, just load the data file given by Great Learning.

# %% [markdown]
# #### Mount google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler

% matplotlib inline

# %% [markdown]
# #### Change your present working directory

# %%
os.chdir("/content/drive/My Drive/Colab Notebooks/LAB9_INT")

# %% [markdown]
# ### Load your data file

# %%
file=pd.read_csv('dataset_lab9.csv',index_col='Date')

# %% [markdown]
# #### Plot data

# %%
file.plot()

# %% [markdown]
# #### Descibe your dataframe

# %%
file.describe()
# Out:
#        Temperature
# count  3650.000000
# mean     11.177753
# std       4.071837
# min       0.000000
# 25%       8.300000
# 50%      11.000000
# 75%      14.000000
# max      26.300000

# %% [markdown]
# From the Describe, we can observe that the Temperature has a standard dev od 4.07 with max and min temp of 0 and 26.3

# %% [markdown]
# #### Check for null values

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3650 entries, 1981-01-01 to 1990-12-31
# Data columns (total 1 columns):
# Temperature    3650 non-null float64
# dtypes: float64(1)
# memory usage: 57.0+ KB

# %% [markdown]
# From the info(), we can observe that there are no null nalues present in the dataset

# %% [markdown]
# #### Drop null values

# %%
file.dropna()
# Out:
#             Temperature
# Date
# 1981-01-01         20.7
# 1981-01-02         17.9
# 1981-01-03         18.8
# 1981-01-04         14.6
# 1981-01-05         15.8
# ...                 ...
# 1990-12-27         14.0
# 1990-12-28         13.6
# 1990-12-29         13.5
# 1990-12-30         15.7
# 1990-12-31         13.0
#
# [3650 rows x 1 columns]

# %% [markdown]
# #### Get the representation of the distribution of data in the form of histogram

# %%
file.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8040162a58>]],
#       dtype=object)

# %% [markdown]
# From the histogram, we can observe that the temp dataset is right skewed

# %% [markdown]
# #### Check the maximum and minimum values

# %%
file['Temperature'].max()
# Out:
# 26.3

# %%
file['Temperature'].min()
# Out:
# 0.0

# %% [markdown]
# ### Normalize the data

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(file)
data=pd.DataFrame(scaled,columns=['Temperature'],index=file.index)

# %%
data.head()
# Out:
#             Temperature
# Date
# 1981-01-01     0.787072
# 1981-01-02     0.680608
# 1981-01-03     0.714829
# 1981-01-04     0.555133
# 1981-01-05     0.600760

# %%
data.describe().T
# Out:
#               count     mean       std  min       25%       50%       75%  max
# Temperature  3650.0  0.42501  0.154823  0.0  0.315589  0.418251  0.532319  1.0

# %% [markdown]
# #### Check the maximum and minimum values of scaled data

# %%
data['Temperature'].max()
# Out:
# 1.0

# %%
data['Temperature'].min()
# Out:
# 0.0

# %% [markdown]
# #### Look into some of the scaled values

# %%
data.head(10)
# Out:
#             Temperature
# Date
# 1981-01-01     0.787072
# 1981-01-02     0.680608
# 1981-01-03     0.714829
# 1981-01-04     0.555133
# 1981-01-05     0.600760
# 1981-01-06     0.600760
# 1981-01-07     0.600760
# 1981-01-08     0.661597
# 1981-01-09     0.828897
# 1981-01-10     0.760456

# %% [markdown]
# ### Split data into Training and Testing

# %%
train_data = data[:int((len(data))*.70)] 
test_data = data[int(len(data)*.70):]

# %% [markdown]
# #### Print train and test size

# %%
train_data.describe().T
# Out:
#               count      mean       std  min       25%       50%       75%  max
# Temperature  2555.0  0.417566  0.155475  0.0  0.307985  0.414449  0.520913  1.0

# %%
test_data.describe().T
# Out:
#               count      mean       std  ...       50%       75%       max
# Temperature  1095.0  0.442377  0.151949  ...  0.441065  0.551331  0.908745
#
# [1 rows x 8 columns]

# %% [markdown]
# ## Create the sequential data
# Map the temprature at a particular time t to the temprature at time t+n, where n is any number you define.
#
# For example: to map tempratures of consecutive days, use t+1, i.e. loop_back = 1

# %% [markdown]
# #### Define your function to create dataset

# %%
def add_col(x):
  x['Nexttemp']=x['Temperature'].shift(-1)
  x=x[:-1]

# %% [markdown]
# #### Use function to get training and test set

# %%
add_col(train_data)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train_data=train_data[:-1]
train_data.tail()
# Out:
#             Temperature  Nexttemp
# Date
# 1987-12-26     0.482890  0.615970
# 1987-12-27     0.615970  0.539924
# 1987-12-28     0.539924  0.543726
# 1987-12-29     0.543726  0.505703
# 1987-12-30     0.505703  0.634981

# %%
add_col(test_data)
test_data=test_data[:-1]
test_data.tail()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Temperature  Nexttemp
# Date
# 1990-12-26     0.555133  0.532319
# 1990-12-27     0.532319  0.517110
# 1990-12-28     0.517110  0.513308
# 1990-12-29     0.513308  0.596958
# 1990-12-30     0.596958  0.494297

# %% [markdown]
# #### Transform the prepared train and test input data into the expected structure using numpy.reshape()

# %%
x_train=train_data['Temperature']
y_train=train_data['Nexttemp']
x_test=test_data['Temperature']
y_test=test_data['Nexttemp']

# %%
x_train=np.reshape(np.array(x_train),(len(x_train),1,1))
x_test=np.reshape(np.array(x_test),(len(x_test),1,1))

# %%
len(x_train)
# Out:
# 2554

# %% [markdown]
# ## Define Model

# %% [markdown]
# ### Define sequntial model, add LSTM layer and compile the model

# %%
tf.keras.backend.clear_session()
model = tf.keras.Sequential()
model.add(tf.keras.layers.LSTM(32, input_shape=(1, 1)))
model.add(tf.keras.layers.Dense(1))
model.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# ### Summarize your model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 32)                4352
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test), batch_size=32)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 2554 samples, validate on 1094 samples
# Epoch 1/100
# 2554/2554 [==============================] - 1s 585us/sample - loss: 0.0795 - val_loss: 0.0215
# Epoch 2/100
# 2554/2554 [==============================] - 0s 140us/sample - loss: 0.0146 - val_loss: 0.0124
# Epoch 3/100
# 2554/2554 [==============================] - 0s 143us/sample - loss: 0.0131 - val_loss: 0.0116
# Epoch 4/100
# 2554/2554 [==============================] - 0s 136us/sample - loss: 0.0124 - val_loss: 0.0110
# Epoch 5/100
# 2554/2554 [==============================] - 0s 151us/sample - loss: 0.0118 - val_loss: 0.0104
# Epoch 6/100
# 2554/2554 [==============================] - 0s 142us/sample - loss: 0.0113 - val_loss: 0.0099
# Epoch 7/100
# 2554/2554 [==============================] - 0s 142us/sample - loss: 0.0108 - val_loss: 0.0095
/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 56/100
# 2554/2554 [==============================] - 0s 96us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 57/100
# 2554/2554 [==============================] - 0s 90us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 58/100
# 2554/2554 [==============================] - 0s 90us/sample - loss: 0.0101 - val_loss: 0.0086
# Epoch 59/100
# 2554/2554 [==============================] - 0s 92us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 60/100
# 2554/2554 [==============================] - 0s 93us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 61/100
# 2554/2554 [==============================] - 0s 90us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 62/100
# 2554/2554 [==============================] - 0s 92us/sample - loss: 0.0101 - val_loss: 0.0086
# Epoch 63/100
# 2554/2554 [==============================] - 0s 93us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 64/100
# 2554/2554 [==============================] - 0s 88us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 65/100
# 2554/2554 [==============================] - 0s 90us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 66/100
# 2554/2554 [==============================] - 0s 91us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 67/100
# 2554/2554 [==============================] - 0s 94us/sample - loss: 0.0101 - val_loss: 0.0086
# Epoch 68/100
# 2554/2554 [==============================] - 0s 91us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 69/100
# 2554/2554 [==============================] - 0s 91us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 70/100
# 2554/2554 [==============================] - 0s 93us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 71/100
# 2554/2554 [==============================] - 0s 90us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 72/100
# 2554/2554 [==============================] - 0s 94us/sample - loss: 0.0101 - val_loss: 0.0086
# Epoch 73/100
# 2554/2554 [==============================] - 0s 89us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 74/100
# 2554/2554 [==============================] - 0s 93us/sample - loss: 0.0101 - val_loss: 0.0089
# Epoch 75/100
# 2554/2554 [==============================] - 0s 91us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 76/100
# 2554/2554 [==============================] - 0s 91us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 77/100
# 2554/2554 [==============================] - 0s 94us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 78/100
# 2554/2554 [==============================] - 0s 90us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 79/100
# 2554/2554 [==============================] - 0s 91us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 80/100
# 2554/2554 [==============================] - 0s 93us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 81/100
# 2554/2554 [==============================] - 0s 91us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 82/100
# 2554/2554 [==============================] - 0s 91us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 83/100
# 2554/2554 [==============================] - 0s 92us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 84/100
# 2554/2554 [==============================] - 0s 101us/sample - loss: 0.0100 - val_loss: 0.0090
# Epoch 85/100
# 2554/2554 [==============================] - 0s 101us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 86/100
# 2554/2554 [==============================] - 0s 91us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 87/100
# 2554/2554 [==============================] - 0s 91us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 88/100
# 2554/2554 [==============================] - 0s 91us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 89/100
# 2554/2554 [==============================] - 0s 92us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 90/100
# 2554/2554 [==============================] - 0s 96us/sample - loss: 0.0101 - val_loss: 0.0087
# Epoch 91/100
# 2554/2554 [==============================] - 0s 89us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 92/100
# 2554/2554 [==============================] - 0s 93us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 93/100
# 2554/2554 [==============================] - 0s 89us/sample - loss: 0.0100 - val_loss: 0.0089
# Epoch 94/100
# 2554/2554 [==============================] - 0s 89us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 95/100
# 2554/2554 [==============================] - 0s 89us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 96/100
# 2554/2554 [==============================] - 0s 95us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 97/100
# 2554/2554 [==============================] - 0s 91us/sample - loss: 0.0100 - val_loss: 0.0087
# Epoch 98/100
# 2554/2554 [==============================] - 0s 91us/sample - loss: 0.0100 - val_loss: 0.0088
# Epoch 99/100
# 2554/2554 [==============================] - 0s 91us/sample - loss: 0.0100 - val_loss: 0.0086
# Epoch 100/100
# 2554/2554 [==============================] - 0s 89us/sample - loss: 0.0100 - val_loss: 0.0089

# %% [markdown]
# ## Make Predictions and Evaluate your model

# %%
trainPredict = model.predict(x_train)
testPredict = model.predict(x_test)

# %%
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Plot the results

# %%
import matplotlib.pyplot as plt
trainPredictPlot = np.empty_like(scaled)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[1:len(trainPredict)+1, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = np.empty_like(scaled)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(1*2):len(scaled), :] = testPredict

# plot baseline and predictions
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(scaled))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
